# %% [markdown]
# <a href="https://colab.research.google.com/github/siu1997/Big-Data-Analytics/blob/main/Practical2/HadoopMapReduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **PRACTICAL 2**

# %% [markdown]
# ### **AIM:**
# To Write and Execute MapReduce code.
# MapReduce - Logical steps with WordCount Program Using Python
# Hadoop Installation
# Hadoop Streaming - Word Count Problem using MapReduce
# Processing weather data set using System streaming, MapReduce and Python

# %% [markdown]
# ###**THEORY:**
# **HADOOP:**
# Hadoop is an open-source framework that allows to store and process big data in a distributed environment across clusters of computers using simple programming models. It is designed to scale up from single servers to thousands of machines, each offering local computation and storage.
#
# **MAPREDUCE:**
# MapReduce is a processing technique and a program model for distributed computing based on java. The MapReduce algorithm contains two important tasks, namely Map and Reduce. Map takes a set of data and converts it into another set of data, where individual elements are broken down into tuples (key/value pairs). Secondly, reduce task, which takes the output from a map as an input and combines those data tuples into a smaller set of tuples. As the sequence of the name MapReduce implies, the reduce task is always performed after the map job.
#
# The major advantage of MapReduce is that it is easy to scale data processing over multiple computing nodes. Under the MapReduce model, the data processing primitives are called mappers and reducers. Decomposing a data processing application into mappers and reducers is sometimes nontrivial. But, once we write an application in the MapReduce form, scaling the application to run over hundreds, thousands, or even tens of thousands of machines in a cluster is merely a configuration change. This simple scalability is what has attracted many programmers to use the MapReduce model.

# %% [markdown]
# ### **Practical 2a MapReduce - WordCount Program Using Python**
#
# Q. Demonstrate the logical working of MapReduce with word count/frequency program using the randomly generated text.

# %% [markdown]
# 1. Generate the dummy text using lorem ipsum text generator in python.

# %%
# !pip install lorem

# %% [markdown]
# Write the lorem text in the ‘ex.txt’ file.

# %%
from lorem import text

with open("ex.txt","w") as f:
    f.write(text())

# %% [markdown]
# Check the contents of the ‘ex.txt file.

# %%
# !cat ex.txt
# Out:
# Quisquam neque etincidunt sit. Etincidunt quiquia porro eius quisquam porro. Aliquam magnam velit modi aliquam consectetur modi. Sed amet modi adipisci aliquam porro consectetur dolor. Est ut magnam magnam etincidunt ut. Porro labore quaerat quiquia dolore sit velit dolor. Eius consectetur dolorem dolore neque magnam dolorem dolor. Velit porro amet quisquam adipisci modi quisquam. Velit porro adipisci etincidunt dolorem tempora amet. Quisquam ut quiquia consectetur ipsum neque consectetur voluptatem.
#
# Modi velit porro quiquia velit. Sit velit quaerat adipisci velit quisquam magnam. Dolor magnam eius quaerat quaerat ipsum. Numquam sed tempora aliquam. Labore dolor amet ut sit quaerat eius. Modi consectetur quaerat quaerat. Ipsum est sit est. Quisquam sit modi ipsum labore est quisquam ipsum. Neque adipisci aliquam est non.
#
# ...

# %% [markdown]
# 2. Write and execute a mapper function.

# %%
def mapper(filename):
    with open(filename) as f:
        data = f.read().strip().lower().replace(".", " ")
    return sorted(map(lambda w:(w,1), data.split()))

# %% [markdown]
# Execute mapper function.

# %%
mapper("ex.txt")

# %% [markdown]
# 3. Write a partition function.

# %%
from collections import defaultdict
def partitioner(map_words):
    d = defaultdict(list)
    for w,i in map_words:
        d[w].append(1)
    return list(d.items())

# %% [markdown]
# Execute partitioner function

# %%
partitioner(mapper("ex.txt"))

# %% [markdown]
# 4. Example reducer function

# %%
def reducer(a):
    lst=[]
    for i in a:
        b= i[0] + ','+ str(len(i[1]))+'\n'
        lst.append(b)
    return lst

# %% [markdown]
# Execute reducer function

# %%
res=reducer(partitioner(mapper("ex.txt")))
res

# %% [markdown]
# ### **Practical 2b Hadoop Installation**

# %% [markdown]
# 1. Download Hadoop

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
# Out:
# --2021-07-20 07:16:46--  https://downloads.apache.org/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.95.219, 135.181.209.10, 135.181.214.104, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.95.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 500749234 (478M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.0.tar.gz’
#
# hadoop-3.3.0.tar.gz 100%[===================>] 477.55M  9.55MB/s    in 50s
#
# 2021-07-20 07:17:38 (9.51 MB/s) - ‘hadoop-3.3.0.tar.gz’ saved [500749234/500749234]

# %% [markdown]
# 2.Extract hadoop installation files

# %%
# !tar -xzvf hadoop-3.3.0.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/FSDataOutputStream.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/TrashPolicyDefault.Emptier.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/HarFileSystem.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/PathExistsException.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/XAttrSetFlag.html
# ...

# %% [markdown]
# 3. Copy  hadoop file to user/local

# %%
# !cp -r hadoop-3.3.0/ /usr/local/

# %% [markdown]
# 4. To find the default Java path

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %% [markdown]
# 5. Install JDK 1.8.0

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %% [markdown]
# 6. Set Java environment

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# Out:
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode
# openjdk version "1.8.0_292"
# OpenJDK Runtime Environment (build 1.8.0_292-8u292-b10-0ubuntu1~18.04-b10)
# OpenJDK 64-Bit Server VM (build 25.292-b10, mixed mode)

# %% [markdown]
# 7. Set Java environment

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-8-openjdk-amd64/jre/

# %% [markdown]
# 8. Running Hadoop

# %%
# !/usr/local/hadoop-3.3.0/bin/hadoop
# Out:
# Usage: hadoop [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#  or    hadoop [OPTIONS] CLASSNAME [CLASSNAME OPTIONS]
#   where CLASSNAME is a user-provided Java class
#
#   OPTIONS is none or any of:
#
# buildpaths                       attempt to add class files from build tree
# --config dir                     Hadoop config directory
# --debug                          turn on shell script debug mode
# --help                           usage information
# hostnames list[,of,host,names]   hosts to use in slave mode
# hosts filename                   list of hosts to use in slave mode
# loglevel level                   set the log4j level for this command
# workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# daemonlog     get/set the log level for each daemon
#
#     Client Commands:
#
# archive       create a Hadoop archive
# checknative   check native Hadoop and compression libraries availability
# ...

# %% [markdown]
# 9. Create the input directory

# %%
# !mkdir ~/input

# %% [markdown]
# 10. Copy all .xml files to input directory

# %%
# !cp /usr/local/hadoop-3.3.0/etc/hadoop/*.xml ~/input

# %% [markdown]
# 11. Execute hadoop jar and hadoop-mapreduce-example  jar files

# %%
# !/usr/local/hadoop-3.3.0/bin/hadoop jar /usr/local/hadoop-3.3.0/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.0.jar grep ~/input ~/grep_example 'allowed[.]*'
# !cat ~/grep_example/*

# %% [markdown]
# ###**Practical 2c Hadoop Streaming - Word Count Problem using MapReduce**
# (In continuation to Practical 2a)

# %% [markdown]
# 12. Create mapper.py file

# %% [markdown]
# 13.  Create reducer.py file.

# %% [markdown]
# 14. Change permissions of mapper.py and reducer.py files.

# %%
# !chmod u+rwx /content/mapper.py
# !chmod u+rwx /content/reducer.py

# %% [markdown]
# 15. Create sample.txt file with your own text

# %% [markdown]
# 16.  Execute MapReduce for the above text file using hadoop and hadoop streaming.

# %%
# !/usr/local/hadoop-3.3.0/bin/hadoop jar /usr/local/hadoop-3.3.0/share/hadoop/tools/lib/hadoop-streaming-3.3.0.jar -input /content/sample.txt -output /content/output2 -file /content/mapper.py  -file /content/reducer.py  -mapper 'python mapper.py'  -reducer 'python reducer.py'
# Out:
# 2021-07-20 07:23:44,549 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper.py, /content/reducer.py] [] /tmp/streamjob2179961953438463805.jar tmpDir=null
# 2021-07-20 07:23:45,284 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2021-07-20 07:23:45,382 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2021-07-20 07:23:45,382 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2021-07-20 07:23:45,398 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2021-07-20 07:23:45,546 INFO mapred.FileInputFormat: Total input files to process : 1
# 2021-07-20 07:23:45,569 INFO mapreduce.JobSubmitter: number of splits:1
# 2021-07-20 07:23:45,778 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1366383211_0001
# 2021-07-20 07:23:45,779 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %% [markdown]
# 17.  Check the output dir

# %%
# !ls /content/output2
# Out:
# part-00000  _SUCCESS

# %% [markdown]
# 18. Display the output in the notebook.

# %%
# !cat /content/output2//part-00000
# Out:
# 1	1
# 2	1
# 3	1
# 4	1
# 5	1
# is	5
# my	5
# name	10
# simran	5

# %% [markdown]
# **Practical 2d - Processing weather data set using MapReduce**

# %% [markdown]
# Q. Find the min and max temperature of a month.

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
# Out:
# --2021-07-20 07:25:37--  https://downloads.apache.org/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.209.10, 88.99.95.219, 135.181.214.104, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.209.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 500749234 (478M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.0.tar.gz.1’
#
# hadoop-3.3.0.tar.gz 100%[===================>] 477.55M  10.7MB/s    in 47s
#
# 2021-07-20 07:26:25 (10.1 MB/s) - ‘hadoop-3.3.0.tar.gz.1’ saved [500749234/500749234]

# %%
# !tar -xzvf hadoop-3.3.0.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/FSDataOutputStream.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/TrashPolicyDefault.Emptier.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/HarFileSystem.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/PathExistsException.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/XAttrSetFlag.html
# ...

# %%
# !cp -r hadoop-3.3.0/ /usr/local/

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-8-openjdk-amd64/jre/

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# Out:
# openjdk version "1.8.0_292"
# OpenJDK Runtime Environment (build 1.8.0_292-8u292-b10-0ubuntu1~18.04-b10)
# OpenJDK 64-Bit Server VM (build 25.292-b10, mixed mode)

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-8-openjdk-amd64/jre/

# %%
# !/usr/local/hadoop-3.3.0/bin/hadoop
# Out:
# Usage: hadoop [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#  or    hadoop [OPTIONS] CLASSNAME [CLASSNAME OPTIONS]
#   where CLASSNAME is a user-provided Java class
#
#   OPTIONS is none or any of:
#
# buildpaths                       attempt to add class files from build tree
# --config dir                     Hadoop config directory
# --debug                          turn on shell script debug mode
# --help                           usage information
# hostnames list[,of,host,names]   hosts to use in slave mode
# hosts filename                   list of hosts to use in slave mode
# loglevel level                   set the log4j level for this command
# workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# daemonlog     get/set the log level for each daemon
#
#     Client Commands:
#
# archive       create a Hadoop archive
# checknative   check native Hadoop and compression libraries availability
# ...

# %%
# !mkdir ~/input
# Out:
# mkdir: cannot create directory ‘/root/input’: File exists

# %%
# !cp /usr/local/hadoop-3.3.0/etc/hadoop/*.xml ~/input

# %%
# !/usr/local/hadoop-3.3.0/bin/hadoop jar /usr/local/hadoop-3.3.0/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.0.jar grep ~/input ~/grep_example 'allowed[.]*'
# !cat ~/grep_example/*
# Out:
# 2021-07-20 07:29:28,656 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2021-07-20 07:29:28,756 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2021-07-20 07:29:28,756 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2021-07-20 07:29:28,942 INFO input.FileInputFormat: Total input files to process : 10
# 2021-07-20 07:29:28,970 INFO mapreduce.JobSubmitter: number of splits:10
# 2021-07-20 07:29:29,174 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1453616667_0001
# 2021-07-20 07:29:29,174 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2021-07-20 07:29:29,363 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2021-07-20 07:29:29,364 INFO mapreduce.Job: Running job: job_local1453616667_0001
# 2021-07-20 07:29:29,372 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# ...

# %%
# !chmod u+rwx /content/mapper1.py
# !chmod u+rwx /content/reducer1.py

# %%
# !/usr/local/hadoop-3.3.0/bin/hadoop jar /usr/local/hadoop-3.3.0/share/hadoop/tools/lib/hadoop-streaming-3.3.0.jar -input /content/weather.txt -output /content/outputw -file /content/mapper1.py  -file /content/reducer1.py  -mapper 'python mapper1.py'  -reducer 'python reducer1.py'
# Out:
# 2021-07-20 07:33:28,653 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper1.py, /content/reducer1.py] [] /tmp/streamjob6899339488327459571.jar tmpDir=null
# 2021-07-20 07:33:29,289 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2021-07-20 07:33:29,390 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2021-07-20 07:33:29,390 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2021-07-20 07:33:29,414 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2021-07-20 07:33:29,605 INFO mapred.FileInputFormat: Total input files to process : 1
# 2021-07-20 07:33:29,628 INFO mapreduce.JobSubmitter: number of splits:1
# 2021-07-20 07:33:29,838 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1333249881_0001
# 2021-07-20 07:33:29,838 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
# !ls /content/outputw
# Out:
# part-00000  _SUCCESS

# %%
# !cat /content/outputw//part-00000
# Out:
# Minimum Temperature : 20100108 -328
# Maximum Temperature : 20100114 39

# %%
# !cat weather.txt | python mapper1.py | python reducer1.py
# Out:
# Minimum Temperature : 20100108 -328
# Maximum Temperature : 20100114 39
